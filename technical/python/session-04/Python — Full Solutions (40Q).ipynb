# %% [markdown]
# ```
# DS Python[4] — Full Solutions (40Q)
#
# Instructor: Eng. Ahmed Salem
# Solved by: Mohamed Mahmoud Salama
# ```

# %%
# 1. Ask the user to enter 5 numbers. Store the numbers in a list. After that,
#  calculate and print the total sum, the average, the largest number, and the smallest number.

# lst = []
# total = 0

# for i in range(0,5) :
#     num = float(input(f"num[{i+1}] = "))
#     lst.append(num)
#     total += num

# average = total / 5

# print(f"The total sum = {total:.2f}\n"
#       f"The Average = {average:.2f}")

# largest_number = max(lst)
# smallest_number = min(lst)

# print(f"The largest number = {largest_number}\n"
#       f"The smallest number = {smallest_number}")

# %%
# 2. Ask the user to enter a number N.
#  Use a for loop to print all numbers from 1 to N that are divisible by 3.
#  For example, if N = 10, the output should be: 3, 6, 9.

# lst = []
# n = int(input("Please, Enter a number N :"))

# for i in range(1,n+1) :
#     if i % 3 == 0 :
#        lst.append(str(i))

# print(", ".join(lst))

# %%
# 3. Given the list numbers = [10, -5, 0, 20, -8, 15, 0, -2],
#  use a loop and conditions to count how many numbers are positive,
#  how many are negative, and how many are equal to zero.

# numbers = [10, -5, 0, 20, -8, 15, 0, -2]

# count_positive = 0
# count_negative = 0
# count_equal_zero = 0

# for i in numbers :

#     if i > 0 :
#         count_positive += 1

#     elif i < 0 :
#         count_negative += 1

#     else :
#         count_equal_zero += 1

# print(f"The number of positive numbers = {count_positive}\n"
#       f"The number of negative numbers = {count_negative}\n"
#       f"The number of numbers equal to zero = {count_equal_zero}")

# %%
# 4. Given the list numbers = [10, 20, 30, 40, 50, 60],
#  first calculate the average of the list.
#  Then create a new list containing only the numbers that are greater than the calculated average.

# numbers = [10, 20, 30, 40, 50, 60]

# average = sum(numbers)/len(numbers)
# print(f"The average = {average}")

# new_lst = []

# for i in numbers :
#     if i > average :
#         new_lst.append(i)

# print(f"New List = {new_lst}")

# %%
# 5. Ask the user to enter a sentence.
#  Use a loop to count how many vowels (a, e, i, o, u) exist in the sentence.
#  Treat uppercase and lowercase letters as the same.

# sentence = input("Enter a sentence : ")

# count_vowels = 0

# for char in sentence :
#      if char.lower() in "aeiou" :
#           count_vowels += 1

# print(f"Number of vowels = {count_vowels}")

# %%
# 6. Given names = ["Ahmed", "Ali", "Mohamed", "Sara", "Omar", "Ibrahim"],
#  use a loop to print only the names that contain more than 4 characters.

# names = ["Ahmed", "Ali", "Mohamed", "Sara", "Omar", "Ibrahim"]

# for name in names :
#     if len(name) > 4 :
#         print(name)

# %%
# 7. Given numbers = [10, 45, 23, 89, 67, 12, 89, 34],
#  find the second largest number in the list without using the sort() function.

# numbers = [10, 45, 23, 89, 67, 12, 89, 34]

# largest = max(numbers)
# second_largest = float('-inf')

# for num in numbers :
#   if num != largest and num > second_largest :
#     second_largest = num

# print(second_largest)

# %%
# 8. Given numbers = [10, 15, 20, 25, 30, 35, 40],
#  use a loop to calculate two separate sums:
#  the sum of all even numbers and the sum of all odd numbers.

# numbers = [10, 15, 20, 25, 30, 35, 40]

# sum_all_even = 0
# sum_all_odd = 0

# for n in numbers :

#     if n % 2 == 0 :
#         sum_all_even += n
#     else :
#         sum_all_odd += n

# print(f"the sum of all even numbers = {sum_all_even}\n"
#       f"the sum of all odd numbers = {sum_all_odd}")

# %%
# 9. Ask the user to enter a number N. Print the multiplication table of N from 1 to 10,
#  but print only the multiplication results that are even.
#  For example, if N = 5, print 10, 20, 30, 40, and 50.

# N = int(input("Enter a number : "))

# for m in range (1,11) :

#     result = N*m

#     if result % 2 == 0 :
#          print(result , end = " ")

# %%
# 10. Given numbers = [1, 2, 2, 3, 4, 4, 5, 6, 6, 7],
#  create a new collection that contains each number only once. The order does not matter.

# numbers = [1, 2, 2, 3, 4, 4, 5, 6, 6, 7]

# Method 1 | Not keep the original order
# new_collection_1 = list(set(numbers))
# print(new_collection_1)


# Method 2 | keep the original order
# new_collection_2 = []

# for n in numbers :

#         if n in new_collection_2 :
#             continue
#         else :
#             new_collection_2.append(n)

# print(new_collection_2)

# %%
# 11. Given list1 = [1, 2, 3, 4, 5] and list2 = [3, 4, 5, 6, 7],
#  create a new list containing only the numbers that exist in both lists.
#  The expected result is [3, 4, 5].

# list1 = [1, 2, 3, 4, 5]
# list2 = [3, 4, 5, 6, 7]

# Method | 1    # order does not matter
# list3 = list(set(list1) & set(list2))
# print(list3)

# Method | 2
# list4 = []
# for i in list1 :
#     if i in list2 :
#             list4.append(i)

# list4 = list(set(list4))    # To prevent repetition
# print(list4)

# %%
# 12. Given list1 = [1, 2, 3, 4] and list2 = [3, 4, 5, 6],
#  create a new collection containing all unique numbers from both lists.
#  The expected result is {1, 2, 3, 4, 5, 6}.

# list1 = [1, 2, 3, 4]
# list2 = [3, 4, 5, 6]

# list3 = set(list1 + list2)
# print(list3)

# %%
# 13. Given numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4],
#  use a dictionary to count how many times each number appears.
#  The expected result is {1: 1, 2: 2, 3: 3, 4: 4}.

# counts = {}
# numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# for num in numbers :
#   if num in counts.keys() :
#     counts[num] += 1
#   else :
#     counts[num] = 1

# print(counts)

# %%
# 14. Given words = ["cat", "house", "python", "car"],
#  create a dictionary where each word is a key and the length of the word is its value.
#  The expected result is {"cat": 3, "house": 5, "python": 6, "car": 3}.

# words = ["cat", "house", "python", "car"]

# dic = {}

# for w in words :
#     dic[w] = len(w)

# print(f"Dictionary = {dic}")

# %%
# 15. Given students = {"Ahmed": 85, "Ali": 55, "Mona": 92, "Sara": 48, "Omar": 70},
#  use a loop to print only the students who passed. A student passes if the grade is 60 or higher.

# students = {"Ahmed": 85, "Ali": 55, "Mona": 92, "Sara": 48, "Omar": 70}

# names_stu_passed = []

# for name , grade in students.items() :
#     if  grade >= 60 :
#         names_stu_passed.append(name)

# print(f"Students who passed: {names_stu_passed}")

# %%
# 16. Given students = {"Ahmed": 85, "Ali": 55, "Mona": 92, "Sara": 48, "Omar": 70},
#  calculate the average grade of all students and print the result.

# students = {"Ahmed": 85, "Ali": 55, "Mona": 92, "Sara": 48, "Omar": 70}

# total = 0
# for grade in students.values() :
#     total += grade

# average = total / len(students)

# print(average)

# %%
# 17. Given products = {"Laptop": 15000, "Phone": 10000, "Mouse": 500, "Keyboard": 1000},
#  find the product with the highest price and print both its name and price. Do not use max() directly on the dictionary.

# products = {"Laptop": 15000, "Phone": 10000, "Mouse": 500, "Keyboard": 1000}

# highest_price = 0
# name_product = ""

# for name , price in products.items() :
#     if  price > highest_price :
#         highest_price = price
#         name_product = name

# print(f"the highest price {highest_price} - {name_product}")

# %%
# 18. Given products = {"Laptop": 15000, "Phone": 10000, "Mouse": 500},
#  increase every product price by 10%. Update the dictionary with the new prices and print the updated dictionary.

# products = {"Laptop": 15000, "Phone": 10000, "Mouse": 500}

# for name , price in products.items() :

#     products[name] = price * 1.1

# print(products)

# %%
# 19. Create a function called count_even(numbers).
#  The function should receive a list of numbers and return how many even numbers exist in the list.
#  Example: count_even([1, 2, 4, 7, 8]) should return 3.

# def count_even(numbers : list) :

#     count = 0

#     for n in numbers :
#          if n % 2 == 0 :
#               count += 1

#     return count

# lst = [1, 2, 4, 7, 8]
# counter = count_even(lst)
# print(counter)

# %%
# 20. Create a function called average_above_50(numbers).
#  The function should receive a list of numbers,
#  calculate the average of only the numbers greater than 50, and return the result.
#  Example: average_above_50([20, 60, 80, 40, 100]) should return 80.

# def average_above_50(numbers : list) :

#     total = 0
#     count = 0

#     for n in numbers :
#         if n > 50 :
#             total += n
#             count += 1

#     if count == 0 :
#        return 0

#     result = total / count
#     return result

# lst = [20, 60, 80, 40, 100]

# average = average_above_50(lst)
# print(f"The average = {average}")

# %%
# 21. Create a function called count_vowels(text).
#  The function should receive a string and return the number of vowels (a, e, i, o, u) in it.
#  The function should treat uppercase and lowercase letters as the same.

# def count_vowels(text : str) :

#     count = 0
#     for t in text :
#         if t.lower() in "aeiou" :
#             count += 1
#     return count

# text = input("Enter a sentence : ")
# result = count_vowels(text)

# print(f"counter = {result}")

# %%
# 22. Create a function called remove_duplicates(items).
#  The function should receive a list and return a new collection containing each element only once.
#  Example: remove_duplicates([1, 2, 2, 3, 3, 4]) should return [1, 2, 3, 4] or an equivalent collection.

# def remove_duplicates(items : list):

#      unique_items = []
#      for l in items :
#           if l not in unique_items :
#                unique_items.append(l)

#      return unique_items

# s = [1, 2, 2, 3, 3, 4]
# lst = remove_duplicates(s)
# print(lst)

# %%
# 23. Create a function called common_elements(list1, list2).
#  The function should receive two lists and return the elements that exist in both lists.
#  Example: common_elements([1, 2, 3], [2, 3, 4]) should return [2, 3].

# def common_elements(list1 : list , list2 : list) :

#     result = []

#     for l in list1 :
#         if l in list2 :
#             result.append(l)

#     return result

# common_items = common_elements([1, 2, 3], [2, 3, 4])
# print(common_items)

# %%
# 24. Create a function called get_divisors(number).
#  The function should receive a positive integer and return all numbers that divide it without a remainder.
#  Example: get_divisors(12) should return [1, 2, 3, 4, 6, 12].

# def get_divisors(number : int) :

#     numbers = []

#     for n in range(1,number+1) :

#         if int(number/n) * n == number :
#             numbers.append(n)
#     return numbers

# print(get_divisors(12))

# %%
# 25. Create a function called check_result(grades).
#  The function should receive a list of grades,
#  calculate the average grade, and return "Pass" if the average is 60 or higher. Otherwise, return "Fail".

# def check_result(grades : list) :

#     average = sum(grades) / len(grades)

#     if average >= 60 :
#         return "Pass"
#     else :
#         return "Fail"

# print(check_result([80,60,88,99,90,77]))

# %%
# 26. Use list comprehension to create a new list containing the squares of all even numbers from 1 to 50.
#  For example, the result should start with [4, 16, 36, 64, ...].

# new_lst = [ e**2 for e in range (1,51) if e % 2 == 0 ]
# print(new_lst)

# %%
# 27. Given names = ["Ahmed", "Mona", "Ali", "Sara"],
#  use list comprehension to create a new list containing the first letter of each name.
#  The expected result is ["A", "M", "A", "S"].

# names = ["Ahmed", "Mona", "Ali", "Sara"]

# new_lst = [ c[0] for c in names]
# print(new_lst)

# %%
# 28. Given numbers = range(1, 51),
#  use list comprehension to create a list containing only numbers that are divisible by both 3 and 5.

# numbers = range(1, 51)
# new_lst = [ n for n in numbers if n % 15 == 0]

# print(new_lst)

# %%
# 29. Given names = ["Ahmed", "Ali", "Mona", "Adam", "Sara", "Amr"],
#  use list comprehension to create a new list containing only names that start with the letter "A".

# names = ["Ahmed", "Ali", "Mona", "Adam", "Sara", "Amr"]
# new_lst = [ c for c in names if c.startswith('A') ]

# print(new_lst)

# %%
# 30. Given sentence = "Python makes programming easier and more fun", split the sentence into words,
#  then use list comprehension to create a list containing the length of each word that has more than 3 characters.

# sentence = "Python makes programming easier and more fun"

# lst_sentence = sentence.split()
# print(lst_sentence)

# new_lst = [ len(s) for s in lst_sentence if len(s) > 3 ]
# print(new_lst)

# %%
# 31. Create a program that keeps asking the user to enter numbers until the user enters 0.
#  Ignore the 0. After the user finishes, print the largest number, smallest number, and average of all entered numbers.
#  You should use a while loop.

# numbers = []

# while True :

#     num = int(input())
#     if num == 0 :
#         break
#     numbers.append(num)

# try :
#      largest = max(numbers)
#      smallest = min(numbers)
#      average = sum(numbers) / len(numbers)

#      print(f"The largest number = {largest}\n"
#           f"The smallest number = {smallest}\n"
#           f"The average = {average}\n")

# except ValueError :
#     print("Not exist numbers")

# %%
# 32. Create a number guessing game. Store a secret number in a variable,
#  for example 25. Keep asking the user to guess the number until they guess correctly.
#  If the guess is greater than the secret number, print "Too High". If it is smaller, print "Too Low".
#  When the user guesses correctly, print "Correct!" and stop the program.

# secret = 25

# while True :
#     s = int(input())

#     if s > secret :
#         print("Too High")

#     elif s < secret :
#         print("Too Low")

#     else :
#         print("Correct!")
#         break

# %%
# 33. Create a menu-driven program using a while loop.
#  The menu should display: 1- Add Number, 2- Show Numbers, 3- Show Sum, 4- Exit.
#  The user can choose an option repeatedly. Add Number should ask for a number and store it in a list.
#  Show Numbers should print all stored numbers. Show Sum should print their total. Exit should stop the program.

# numbers = []

# def add_numbers() :

#     number = int(input("Enter a number : "))
#     numbers.append(number)

# def show_numbers() :
#     print(numbers)

# def show_sum (lst : list) :

#     if len(lst) != 0 :
#            total = sum(lst)
#            print(total)
#     else :
#            total = 0
#            print(total)


# while True :

#     print("1- Add Number\n"
#           "2- Show Numbers\n"
#           "3- Show Sum\n"
#           "4- Exit")



#     try :

#        num_operation = int(input("Enter a operated number : "))

#        if (num_operation >= 1 and num_operation <= 4) :


#          if num_operation == 1 :
#              add_numbers()
#          elif num_operation == 2 :
#              show_numbers()
#          elif num_operation == 3 :
#              show_sum(numbers)
#          elif num_operation == 4 :
#              break
#        else :
#          print("Please, An operated number to 1 from 4")
#          continue

#     except ValueError :
#         print("Must be 'integar' number")

# %%
# 34. Create a simple shopping cart program. Store available products and their prices in a dictionary.
#  Display the available products to the user. Ask the user to enter product names and add the selected products to a cart until the user enters "done".
#  At the end, print all selected products and the total price. If the user enters a product that does not exist, print an error message.

# products = {
#     "Laptop": 15000,
#     "Phone": 10000,
#     "Tablet": 7000,
#     "Mouse": 500,
#     "Keyboard": 1000,
#     "Monitor": 4500,
#     "Headphones": 1200,
#     "Smart Watch": 3500,
#     "Printer": 2800,
#     "Webcam": 900,
#     "USB Flash Drive": 250,
#     "External Hard Drive": 2000,
#     "Speaker": 1500,
#     "Charger": 350,
#     "Power Bank": 800
# }

# print("\nThe available products : \n")
# for name , price in products.items() :
#     print(f"{name.ljust(20)} - {str(price).ljust(6)}EGP")

# cart = []

# while True :

#     name_product = input("Enter product names : ").strip()

#     if name_product.lower() == "done" :
#         break

#     found = None
#     for p in products :
#         if p.lower() == name_product.lower() :
#             found = p

#     if found :
#         cart.append(found)

#     else :
#         print("An error message, This product does not exist!")

# total = 0

# for c in cart :
#     total += products[c]

# print(f"All selected products = {cart} \n"
#       f"The total price = {total}")

# %%
# 35. Create a login system using a dictionary that contains usernames and passwords.
#  Ask the user to enter a username and password. The user has only 3 attempts to enter valid information.
#  If the login is correct, print "Login Successful" and stop. If all 3 attempts are wrong, print "Account Locked".

# users = {
#     "ahmed": "ahmed123",
#     "sara": "sara456",
#     "mohamed": "mohamed789",
#     "youssef": "yossef2024",
#     "nour": "nour_pass",
#     "mona": "mona_2025",
#     "khaled": "kh@led99",
#     "laila": "laila123"
# }

# found = False

# for _ in range (0,3) :

#     username = input("Enter a username : ")
#     password = input("Enter a password : ")

#     if username in users.keys() :

#         if password == users[username] :
#             found = True
#             break
#         else :
#             print("password is unsuccessful")

#     else :
#         print("Username is unsuccessful")



# if found :
#     print ("Login Successful")
# else :
#     print ("Account Locked")

# %%
# 36. Ask the user to enter a sentence. Create a dictionary where each word is a key and the number of times that word appears is the value.
#  Example: if the user enters "python is easy and python is powerful", the dictionary should count python twice and is twice.

# sentence = input("Enter a sentence : ")
# dic = {}
# word = sentence.split()

# for w in word :
#     counter = word.count(w)
#     dic[w] = counter

# print(dic)

# %%
# 37. Given students = {"Ahmed": [80, 90, 70], "Ali": [60, 75, 80], "Mona": [95, 90, 100]}, calculate the average grade for every student.
#  Print each student's name and average, then print the name of the student with the highest average.

# students = {"Ahmed": [80, 90, 70],  "Mona": [95, 90, 100], "Ali": [60, 75, 80]}

# averages = {}

# for name , grades in students.items() :
#     average = sum(grades) / len(grades)
#     averages[name] = average


# name_student = ""
# highest_average = -1

# for name , average in averages.items() :

#     print(f"{name} : {average:.2f}")

#     if average > highest_average :
#         highest_average = average
#         name_student = name

# print(f"The student with the highest average : {name_student}")

# %%
# 38. Given transactions = [100, -50, 200, -30, -20, 500],
#  treat positive numbers as deposits and negative numbers as withdrawals.
#  Calculate and print the final balance, total deposited amount, and total withdrawn amount.
#  For this example, the final balance should be 700.

# transactions = [100, -50, 200, -30, -20, 500]

# total_deposited = 0
# total_withdrawn = 0

# for t in transactions :

#     if t > 0 :
#         total_deposited += t
#     elif t < 0 :
#         total_withdrawn += t

# final_balance = total_deposited + total_withdrawn

# print(f"The final balance = {final_balance}\n"
#       f"The total deposited = {total_deposited}\n"
#       f"The total withdrawn = {total_withdrawn}")

# %%
# 39. Create a simple ATM program using a while loop. Start with a balance of 5000.
#  Display a menu with: 1- Deposit, 2- Withdraw, 3- Check Balance, 4- Exit. Deposit should increase the balance, Withdraw should decrease it only if there is enough money,
#  Check Balance should display the current balance, and Exit should stop the program.

# balance = 5000

# def deposit(money : int) :
#     global balance
#     balance += money

# def withdraw(money : int) :
#     global balance

#     if money > balance :
#         print("Insufficient balance!")
#         print(f"Current balance: {balance}\n")
#     else :
#         balance -= money

# def check_balance() :
#     print(f"Current balance: {balance}")


# while True :

#     print("\n1- Deposit\n"
#           "2- Withdraw\n"
#           "3- Check Balance\n"
#           "4- Exit")

#     number_operated = int(input("Enter a operation number : "))

#     if number_operated >= 1 and number_operated <= 4 :

#         if number_operated == 1 :
#             number_deposited = int(input("The number deposited it = "))
#             deposit(number_deposited)

#         elif number_operated == 2 :
#             number_withdrawn = int(input("The number withdrawn it = \n"))
#             withdraw(number_withdrawn)

#         elif number_operated == 3 :
#             check_balance()

#         elif number_operated == 4 :
#             print("\nThank you for trusting us (:")
#             break

#     else :
#         print("\nPlease, Enter a operation number to 1 from 4 (:\n")

# %%
# 40. Create a Student Management System using a dictionary.
#  Each student should have a list of grades.
#  Create a menu using while that allows the user to: Add Student, Add Grade, Show Student Average,
#  Show All Students, Find the Top Student, and Exit. Organize the program using functions, and use lists,
#  dictionaries, loops, conditions, and list comprehension where they are useful.

# student_system = {}

# def add_student(name : str) :
#     if name in student_system :
#         print(f"{name} already exists!")
#     else :
#         student_system[name] = []
#         print(f"{name} added successfully.")



# def add_grade(name , grade) :
#     if name in student_system :
#         student_system[name].append(float(grade))
#         print(f"Grade {grade} added to {name}.")
#     else :
#         print(f"{name} does not exist! Add the student first.")



# def average_student(name) :
#     if name in student_system :
#         grades = student_system[name]
#         if grades  :
#             average = sum(grades) / len(grades)
#             print(f"{name}'s average = {average:.2f}")
#         else :
#             print(f"{name} has no grades yet.")
#     else :
#         print(f"{name} does not exist!")



# def show_all_students() :
#     if not student_system:
#         print("No students yet.")
#         return
#     else :
#         for name,grades in student_system.items() :
#             if grades :
#                average = sum(grades) / len(grades)
#             else :
#                 average = 0

#             print(f"{name.ljust(10)}  -  Grades = {grades}  -  Average = {average:.2f} ")



# def top_student() :

#     average_students = {}

#     if not student_system :

#         print("No students yet.")
#         return
#     else :

#         for name , grades in student_system.items() :
#             if grades :
#                average_students[name] = sum(grades)/len(grades)
#             else :
#                 average_students[name] = 0

#     the_best = max(average_students , key = average_students.get)
#     print(f"Top Student is {the_best} with average = {average_students[the_best]:.2f}")


# def menu() :

#     while True :

#         print("\n---- Student Management System ----\n"
#               "1. Add Student\n"
#               "2. Add Grade\n"
#               "3. Show Student Average\n"
#               "4. Show All Students\n"
#               "5. Find Top Student\n"
#               "6. Exit")

#         try :
#           choice = int(input("Please, Enter your choice : "))


#           if choice == 1 :
#                 name_student = input("Enter student name : ").strip().title()
#                 add_student(name_student)

#           elif choice == 2 :

#                 name_student = input("Enter student name : ").strip().title()

#                 if name_student not in student_system :
#                     print(f"{name_student} does not exist! Add the student first.")

#                 else :

#                  while True :
#                     grades = input("Enter 'student grades'  or 'done' : ")
#                     if grades.lower() == "done" :
#                         print(f"All grades have been added for {name_student}")
#                         break

#                     try :
#                         grade_value = float(grades)
#                     except ValueError :
#                         print("Please enter a valid number or 'done'.")
#                         continue

#                     if grade_value >=0 and grade_value <=100 :
#                         add_grade(name_student , grade_value)

#                     else :
#                         print("Study material grades are up to 100 points")

#           elif choice == 3 :
#                 name_student = input("Enter student name : ").strip().title()
#                 average_student(name_student)

#           elif choice == 4 :
#                 show_all_students()

#           elif choice == 5 :
#                 top_student()

#           elif choice == 6 :
#                 print("The operation is over. I wish everyone a happy time (:")
#                 break

#           else :
#                 print("\nPlease, Enter a choices to 1 from 6 \ntry again (:")

#         except ValueError :
#             print("Please enter a number!")

# menu()
